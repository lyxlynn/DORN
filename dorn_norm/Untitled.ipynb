# %%
import scipy.io
import matplotlib.pyplot as plt
import cv2
d=scipy.io.loadmat('/data/liuyx/nyuv2/nyu_depth_v2_train_fill_every10/office_0003/00005_dep.mat')['depthOut']
img= cv2.imread('/data/liuyx/nyuv2/nyu_depth_v2_train_fill_every10/office_0003/00005_rgb.png')
pred= cv2.imread('./outputs_val/debug.png')

# %%
plt.imshow(d)
d.shape
from dataset.datasets import LIPParsingEdgeDataSet
a=LIPParsingEdgeDataSet('dataset/list/nyuv2/train_rgb.txt','dataset/list/nyuv2/train_rgb.txt')
a.get_depth_sid(d)
# Out:
# ------------------------------------------------------------------
# NameError                        Traceback (most recent call last)
# <ipython-input-84-cb7e473035bf> in <module>()
#       2 d.shape
#       3 from dataset.datasets import LIPParsingEdgeDataSet
# ----> 4 a=LIPParsingEdgeDataSet('dataset/list/nyuv2/train_rgb.txt','dataset/list/nyuv2/train_rgb.txt')
#       5 a.get_depth_sid(d)
#
# ~/depth/DORN_pytorch/dataset/datasets.py in __init__(self, root, list_path, max_iters, crop_size, mean, scale, mirror, ignore_label)
#      28             self.tot_len = max_iters
#      29         else:
# ---> 30             self.tot_len = len(self.img_ids)
#      31             #self.img_ids = self.img_ids * int(np.ceil(float(max_iters) / len(self.img_ids)))
#      32
#
# NameError: name 'sel' is not defined

# %%
plt.imshow(pred)

# %%
pred
# Out:
# array([[[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [ 23,  23,  23],
#         [ 23,  23,  23],
#         [ 23,  23,  23]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [ 23,  23,  23],
#         [ 23,  23,  23],
#         [ 23,  23,  23]],
#
#        [[137, 137, 137],
#         [137, 137, 137],
#         [137, 137, 137],
#         ...,
#         [ 23,  23,  23],
#         [ 23,  23,  23],
#         [ 23,  23,  23]],
#
#        ...,
#
#        [[120, 120, 120],
#         [120, 120, 120],
#         [120, 120, 120],
#         ...,
#         [ 11,  11,  11],
#         [ 11,  11,  11],
#         [ 11,  11,  11]],
#
#        [[120, 120, 120],
#         [120, 120, 120],
#         [120, 120, 120],
#         ...,
#         [ 11,  11,  11],
#         [ 11,  11,  11],
#         [ 11,  11,  11]],
#
#        [[120, 120, 120],
#         [120, 120, 120],
#         [120, 120, 120],
# ...

# %%
import  numpy as np
pred2=np.load('depth_pred.npy')

# %%
np.minpred)
# Out:
#   File "<ipython-input-46-738b4a34b995>", line 1
#     np.minpred)
#               ^
# SyntaxError: invalid syntax

# %%
plt.imshow(pred)

# %%
np.min(pred)
# Out:
# 2.3171186

# %%
plt.imshow(pred2)

# %%
pred2.shape
# Out:
# (427, 561)

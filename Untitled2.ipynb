# %%
depth = sio.loadmat(path_l)['depthOut']
np.sum(depth-label_ori)
plt.imshow(depth)

# %%
plt.imshow(label)

# %%
c=np.resize(label_ori,(473,473))
label_ori.shape
# Out:
# (427, 561)

# %%
import cv2
c=cv2.resize(label_ori,(473,473))
plt.imshow(c)

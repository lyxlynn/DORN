# %%
from dataset.datasets import LIPParsingEdgeDataSet 
import matplotlib.pyplot as plt
import numpy as np
a=LIPParsingEdgeDataSet ('./home/sdc/nyu_depth_v2_train_fill_all','/home/sdc/nyu_depth_v2_train_fill_all/train_rgb.txt',30)
img,label,label_ori,__,name,path_l=a[0]
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-28-62076ee9562e> in <module>
#       3 import numpy as np
#       4 a=LIPParsingEdgeDataSet ('./home/sdc/nyu_depth_v2_train_fill_all','/home/sdc/nyu_depth_v2_train_fill_all/train_rgb.txt',30)
# ----> 5 img,label,label_ori,__,name,path_l=a[0]
#
# ValueError: not enough values to unpack (expected 6, got 5)

# %%
plt.imshow((label*25.5).astype(int))

# %%
plt.imshow((label_ori*25.5).astype(int))

# %%
plt.imshow(img)

# %%
print(label_ori)
# Out:
# [[2.27349405 2.27349405 2.27349405 ... 2.57461909 2.57461909 2.57461909]
#  [2.28855031 2.28855031 2.28855031 ... 2.57461909 2.57461909 2.57461909]
#  [2.28855031 2.28855031 2.28855031 ... 2.57461909 2.57461909 2.55956284]
#  ...
#  [0.96360013 0.96360013 0.96360013 ... 1.83686275 1.82180649 1.82180649]
#  [0.96360013 0.94854388 0.94854388 ... 1.82180649 1.82180649 1.82180649]
#  [0.94854388 0.94854388 0.94854388 ... 1.82180649 1.82180649 1.82180649]]

# %%
from scipy import misc

misc.imsave('d.png',label)
# Out:
# /home/sda/lyx/enter/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
name
# Out:
# '00405_dep'
